# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('covid.csv')

# %%
df.head()
# Out:
#          date  Cases  Death_Cases  Recovered_Cases  Confirmed  Deaths  \
# 0  2020-03-15      1          0.0              0.0          1     0.0
# 1  2020-03-16      5          0.0              0.0          6     0.0
# 2  2020-03-17      4          0.0              0.0         10     0.0
# 3  2020-03-18      5          0.0              0.0         15     0.0
# 4  2020-03-19      8          0.0              0.0         23     0.0
#
#    Recovered     Country
# 0        0.0  Uzbekistan
# 1        0.0  Uzbekistan
# 2        0.0  Uzbekistan
# 3        0.0  Uzbekistan
# 4        0.0  Uzbekistan

# %%
df.tail()
# Out:
#            date  Cases  Death_Cases  Recovered_Cases  Confirmed  Deaths  \
# 500  2021-07-28    843          8.0            825.0     126627   853.0
# 501  2021-07-29    879          6.0            573.0     127506   859.0
# 502  2021-07-30    897          7.0            650.0     128403   866.0
# 503  2021-07-31    924          8.0            796.0     129327   874.0
# 504  2021-08-01    889          6.0            831.0     130216   880.0
#
#      Recovered     Country
# 500   121145.0  Uzbekistan
# 501   121718.0  Uzbekistan
# 502   122368.0  Uzbekistan
# 503   123164.0  Uzbekistan
# 504   123995.0  Uzbekistan

# %%
x = df ['date']
y = df ['Cases']
plt.plot(x, y)

plt.title('covid 19 data of uz')
plt.xlabel('date')
plt.ylabel('new cases')
plt.legend('daily new cases')
plt.show()
